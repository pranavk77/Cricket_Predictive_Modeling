# %%
import pandas as pd
import numpy as np
import pickle
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv(r'E:\Data_Sci\DATA\ipl.csv')

# %%
df
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                      ...                          ...          ...
# 76009         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76010         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76011         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76012         Mumbai Indians       Rising Pune Supergiant   MG Johnson
# 76013         Mumbai Indians       Rising Pune Supergiant    KH Pandya
#
#              bowler  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 0           P Kumar     1        0    0.1            1               0
# 1           P Kumar     1        0    0.2            1               0
# 2           P Kumar     2        0    0.2            2               0
# 3           P Kumar     2        0    0.3            2               0
# 4           P Kumar     2        0    0.4            2               0
# ...             ...   ...      ...    ...          ...             ...
# 76009  DT Christian   121        7   19.2           40               0
# 76010  DT Christian   127        7   19.3           46               0
# 76011  DT Christian   128        7   19.4           47               0
# 76012  DT Christian   129        7   19.5           48               0
# 76013  DT Christian   129        8   19.6           47               1
#
#        striker  non-striker  total
# 0            0            0    222
# 1            0            0    222
# 2            0            0    222
# 3            0            0    222
# 4            0            0    222
# ...        ...          ...    ...
# 76009       40           12    129
# 76010       46           12    129
# 76011       47           12    129
# 76012       47           13    129
# 76013       47           13    129
#
# [76014 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
columns_to_remove = ['mid','striker', 'non-striker','date']
df.drop(labels=columns_to_remove, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['venue', 'bat_team', 'bowl_team', 'batsman', 'bowler', 'runs',
#        'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'total'],
#       dtype='object')

# %%
df['bowl_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
playing_teams=['Royal Challengers Bangalore', 'Kings XI Punjab',
       'Delhi Daredevils', 'Kolkata Knight Riders', 'Rajasthan Royals',
       'Mumbai Indians', 'Chennai Super Kings', 'Deccan Chargers',
       'Sunrisers Hyderabad','Rising Pune Supergiants', 'Gujarat Lions',
       'Rising Pune Supergiant']

# %%
df = df[(df['bat_team'].isin(playing_teams)) & (df['bowl_team'].isin(playing_teams))]

# %%
df = df[df['overs']>=5.0]

# %%
df
# Out:
#                                            venue               bat_team  \
# 32                         M Chinnaswamy Stadium  Kolkata Knight Riders
# 33                         M Chinnaswamy Stadium  Kolkata Knight Riders
# 34                         M Chinnaswamy Stadium  Kolkata Knight Riders
# 35                         M Chinnaswamy Stadium  Kolkata Knight Riders
# 36                         M Chinnaswamy Stadium  Kolkata Knight Riders
# ...                                          ...                    ...
# 76009  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76010  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76011  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76012  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76013  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
#                          bowl_team      batsman        bowler  runs  wickets  \
# 32     Royal Challengers Bangalore  BB McCullum        Z Khan    61        0
# 33     Royal Challengers Bangalore   SC Ganguly        Z Khan    61        1
# 34     Royal Challengers Bangalore   RT Ponting        Z Khan    61        1
# 35     Royal Challengers Bangalore   RT Ponting        Z Khan    61        1
# 36     Royal Challengers Bangalore   RT Ponting        Z Khan    61        1
# ...                            ...          ...           ...   ...      ...
# 76009       Rising Pune Supergiant    KH Pandya  DT Christian   121        7
# 76010       Rising Pune Supergiant    KH Pandya  DT Christian   127        7
# 76011       Rising Pune Supergiant    KH Pandya  DT Christian   128        7
# 76012       Rising Pune Supergiant   MG Johnson  DT Christian   129        7
# 76013       Rising Pune Supergiant    KH Pandya  DT Christian   129        8
#
#        overs  runs_last_5  wickets_last_5  total
# 32       5.1           59               0    222
# 33       5.2           59               1    222
# 34       5.3           59               1    222
# 35       5.4           59               1    222
# 36       5.5           58               1    222
# ...      ...          ...             ...    ...
# 76009   19.2           40               0    129
# 76010   19.3           46               0    129
# 76011   19.4           47               0    129
# 76012   19.5           48               0    129
# 76013   19.6           47               1    129
#
# [51451 rows x 11 columns]

# %%
df["bat_team"].replace({"Deccan Chargers": "Sunrisers Hyderabad", "Rising Pune Supergiants": "Chennai Super Kings","Gujarat Lions":"Rajasthan Royals","Rising Pune Supergiant": "Chennai Super Kings"}, inplace=True)
df["bowl_team"].replace({"Deccan Chargers": "Sunrisers Hyderabad", "Rising Pune Supergiants": "Chennai Super Kings","Gujarat Lions":"Rajasthan Royals","Rising Pune Supergiant": "Chennai Super Kings"}, inplace=True)

# %%
df['bowl_team'].unique()
df['bat_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Sunrisers Hyderabad', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils'], dtype=object)

# %%
df['venue'].nunique()
# Out:
# 34

# %%
encoded_df = pd.get_dummies(data=df, columns=['bat_team', 'bowl_team'])
encoded_df
# Out:
#                                            venue      batsman        bowler  \
# 32                         M Chinnaswamy Stadium  BB McCullum        Z Khan
# 33                         M Chinnaswamy Stadium   SC Ganguly        Z Khan
# 34                         M Chinnaswamy Stadium   RT Ponting        Z Khan
# 35                         M Chinnaswamy Stadium   RT Ponting        Z Khan
# 36                         M Chinnaswamy Stadium   RT Ponting        Z Khan
# ...                                          ...          ...           ...
# 76009  Rajiv Gandhi International Stadium, Uppal    KH Pandya  DT Christian
# 76010  Rajiv Gandhi International Stadium, Uppal    KH Pandya  DT Christian
# 76011  Rajiv Gandhi International Stadium, Uppal    KH Pandya  DT Christian
# 76012  Rajiv Gandhi International Stadium, Uppal   MG Johnson  DT Christian
# 76013  Rajiv Gandhi International Stadium, Uppal    KH Pandya  DT Christian
#
#        runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 32       61        0    5.1           59               0    222
# 33       61        1    5.2           59               1    222
# 34       61        1    5.3           59               1    222
# 35       61        1    5.4           59               1    222
# 36       61        1    5.5           58               1    222
# ...     ...      ...    ...          ...             ...    ...
# 76009   121        7   19.2           40               0    129
# 76010   127        7   19.3           46               0    129
# 76011   128        7   19.4           47               0    129
# 76012   129        7   19.5           48               0    129
# 76013   129        8   19.6           47               1    129
#
#        bat_team_Chennai Super Kings  ...  \
# 32                                0  ...
# 33                                0  ...
# 34                                0  ...
# 35                                0  ...
# 36                                0  ...
# ...                             ...  ...
# 76009                             0  ...
# 76010                             0  ...
# 76011                             0  ...
# 76012                             0  ...
# 76013                             0  ...
#
#        bat_team_Royal Challengers Bangalore  bat_team_Sunrisers Hyderabad  \
# 32                                        0                             0
# 33                                        0                             0
# 34                                        0                             0
# 35                                        0                             0
# 36                                        0                             0
# ...                                     ...                           ...
# 76009                                     0                             0
# 76010                                     0                             0
# 76011                                     0                             0
# 76012                                     0                             0
# 76013                                     0                             0
#
#        bowl_team_Chennai Super Kings  bowl_team_Delhi Daredevils  \
# 32                                 0                           0
# 33                                 0                           0
# 34                                 0                           0
# 35                                 0                           0
# 36                                 0                           0
# ...                              ...                         ...
# 76009                              1                           0
# 76010                              1                           0
# 76011                              1                           0
# 76012                              1                           0
# 76013                              1                           0
#
#        bowl_team_Kings XI Punjab  bowl_team_Kolkata Knight Riders  \
# 32                             0                                0
# 33                             0                                0
# 34                             0                                0
# 35                             0                                0
# 36                             0                                0
# ...                          ...                              ...
# 76009                          0                                0
# 76010                          0                                0
# 76011                          0                                0
# 76012                          0                                0
# 76013                          0                                0
#
#        bowl_team_Mumbai Indians  bowl_team_Rajasthan Royals  \
# 32                            0                           0
# 33                            0                           0
# 34                            0                           0
# 35                            0                           0
# 36                            0                           0
# ...                         ...                         ...
# 76009                         0                           0
# 76010                         0                           0
# 76011                         0                           0
# 76012                         0                           0
# 76013                         0                           0
#
#        bowl_team_Royal Challengers Bangalore  bowl_team_Sunrisers Hyderabad
# 32                                         1                              0
# 33                                         1                              0
# 34                                         1                              0
# 35                                         1                              0
# 36                                         1                              0
# ...                                      ...                            ...
# 76009                                      0                              0
# 76010                                      0                              0
# 76011                                      0                              0
# 76012                                      0                              0
# 76013                                      0                              0
#
# [51451 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoded_df['venue'] = LabelEncoder().fit_transform(encoded_df['venue'].tolist())
encoded_df['batsman'] = LabelEncoder().fit_transform(encoded_df['batsman'].tolist())
encoded_df['bowler'] = LabelEncoder().fit_transform(encoded_df['bowler'].tolist())

encoded_df
# Out:
#        venue  batsman  bowler  runs  wickets  overs  runs_last_5  \
# 32        14       57     311    61        0    5.1           59
# 33        14      300     311    61        1    5.2           59
# 34        14      278     311    61        1    5.3           59
# 35        14      278     311    61        1    5.4           59
# 36        14      278     311    61        1    5.5           58
# ...      ...      ...     ...   ...      ...    ...          ...
# 76009     22      162      93   121        7   19.2           40
# 76010     22      162      93   127        7   19.3           46
# 76011     22      162      93   128        7   19.4           47
# 76012     22      201      93   129        7   19.5           48
# 76013     22      162      93   129        8   19.6           47
#
#        wickets_last_5  total  bat_team_Chennai Super Kings  ...  \
# 32                  0    222                             0  ...
# 33                  1    222                             0  ...
# 34                  1    222                             0  ...
# 35                  1    222                             0  ...
# 36                  1    222                             0  ...
# ...               ...    ...                           ...  ...
# 76009               0    129                             0  ...
# 76010               0    129                             0  ...
# 76011               0    129                             0  ...
# 76012               0    129                             0  ...
# 76013               1    129                             0  ...
#
#        bat_team_Royal Challengers Bangalore  bat_team_Sunrisers Hyderabad  \
# 32                                        0                             0
# 33                                        0                             0
# 34                                        0                             0
# 35                                        0                             0
# 36                                        0                             0
# ...                                     ...                           ...
# 76009                                     0                             0
# 76010                                     0                             0
# 76011                                     0                             0
# 76012                                     0                             0
# 76013                                     0                             0
#
#        bowl_team_Chennai Super Kings  bowl_team_Delhi Daredevils  \
# 32                                 0                           0
# 33                                 0                           0
# 34                                 0                           0
# 35                                 0                           0
# 36                                 0                           0
# ...                              ...                         ...
# 76009                              1                           0
# 76010                              1                           0
# 76011                              1                           0
# 76012                              1                           0
# 76013                              1                           0
#
#        bowl_team_Kings XI Punjab  bowl_team_Kolkata Knight Riders  \
# 32                             0                                0
# 33                             0                                0
# 34                             0                                0
# 35                             0                                0
# 36                             0                                0
# ...                          ...                              ...
# 76009                          0                                0
# 76010                          0                                0
# 76011                          0                                0
# 76012                          0                                0
# 76013                          0                                0
#
#        bowl_team_Mumbai Indians  bowl_team_Rajasthan Royals  \
# 32                            0                           0
# 33                            0                           0
# 34                            0                           0
# 35                            0                           0
# 36                            0                           0
# ...                         ...                         ...
# 76009                         0                           0
# 76010                         0                           0
# 76011                         0                           0
# 76012                         0                           0
# 76013                         0                           0
#
#        bowl_team_Royal Challengers Bangalore  bowl_team_Sunrisers Hyderabad
# 32                                         1                              0
# 33                                         1                              0
# 34                                         1                              0
# 35                                         1                              0
# 36                                         1                              0
# ...                                      ...                            ...
# 76009                                      0                              0
# 76010                                      0                              0
# 76011                                      0                              0
# 76012                                      0                              0
# 76013                                      0                              0
#
# [51451 rows x 25 columns]

# %%
#calculate and round off correlation matrix
corMat = (encoded_df.iloc[:,:10].corr()).values
corMat = np.around(corMat, decimals = 3)
print(corMat)
# Out:
# [[ 1.    -0.028 -0.014 -0.015  0.011  0.002 -0.011 -0.003 -0.019 -0.021]
#  [-0.028  1.     0.021 -0.028 -0.045 -0.05   0.003 -0.021  0.032  0.08 ]
#  [-0.014  0.021  1.    -0.011  0.001 -0.008 -0.003  0.009 -0.014  0.017]
#  [-0.015 -0.028 -0.011  1.     0.376  0.885  0.574  0.118  0.38   0.032]
#  [ 0.011 -0.045  0.001  0.376  1.     0.641 -0.191  0.632 -0.445 -0.072]
#  [ 0.002 -0.05  -0.008  0.885  0.641  1.     0.285  0.22   0.028  0.002]
#  [-0.011  0.003 -0.003  0.574 -0.191  0.285  1.    -0.281  0.569  0.043]
#  [-0.003 -0.021  0.009  0.118  0.632  0.22  -0.281  1.    -0.294 -0.058]
#  [-0.019  0.032 -0.014  0.38  -0.445  0.028  0.569 -0.294  1.     0.066]
#  [-0.021  0.08   0.017  0.032 -0.072  0.002  0.043 -0.058  0.066  1.   ]]

# %%
feature_importance = (encoded_df.iloc[:,:10].corr()).iloc[:-1, -1].sort_values(ascending=False)
print('Features in Descending Order of Importance', list(feature_importance.index))
# Out:
# Features in Descending Order of Importance ['batsman', 'total', 'runs_last_5', 'runs', 'bowler', 'overs', 'venue', 'wickets_last_5', 'wickets']

# %%
# Rearranging the columns
encoded_df = encoded_df[['batsman', 'total', 'runs_last_5', 'runs', 'bowler', 'overs', 'venue', 'wickets_last_5', 'wickets','bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
              'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
              'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
              'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils', 'bowl_team_Kings XI Punjab',
              'bowl_team_Kolkata Knight Riders', 'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
              'bowl_team_Royal Challengers Bangalore', 'bowl_team_Sunrisers Hyderabad',]]

# %%
from sklearn.model_selection import train_test_split

from sklearn import metrics
y = encoded_df["total"]
X = encoded_df.drop(columns="total")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
import xgboost as xgb
xgbr = xgb.XGBRegressor(verbosity=0) 
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(X_train, y_train)  
print("Training score: ", score)
# Out:
# Training score:  0.926327015365558

# %%
y_pred1 = xgbr.predict(X_test)

# %%
y_pred1
# Out:
# array([113.15347,  67.28833, 169.33034, ..., 142.87723, 148.65704,
#        213.39458], dtype=float32)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(y_test,label='rings actual')
sns.kdeplot(y_pred1,label='rings predicted')
plt.legend()
